# %%
import json
import matplotlib
import numpy as np
import scipy
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %matplotlib inline

# %% [markdown]
# $f(x) = x^3 - 4x^2 - 7x +13$
#
# $f'(x) = 3x^2 - 8x - 7$
#
# $\varphi(x) = x - \lambda f(x)$

# %%
EPS = 1e-4
def f(x):
    return x**3 - 4*x**2 - 7*x + 13
def df(x):
    return 3*x**2 - 8*x - 7
def phi(x, _lambda):
    return x - _lambda * f(x)

# %% [markdown]
# Розглянемо графік функції $f(x)$

# %%
y = np.arange(-5,7,0.01)
plt.figure(figsize=(12,10))
plt.grid(color='gray', linestyle='-', linewidth=1)
plt.plot(y, f(y))

# %% [markdown]
# ## Метод простої ітерації

# %% [markdown]
# Потім ми будемо використовувати цю ж функцію для методу релаксації

# %%
def simple_iteration(x_start, color, _lambda):
    x = x_start
    plt.plot(x, f(x), color+'x')
    iteration_count = 0
    print("Start point is {}".format(x_start))
    while True:
        new_x = phi(x, _lambda)
        print("From {: 3.6f} to {: 3.6f}   f(x)={: 10.8f}".format(x, new_x, f(x)))
        plt.plot(x,f(x), color+'.')
        iteration_count += 1
        if abs(new_x - x) < EPS:
            break
        x = new_x
    print("Ended with {:2d} iterations".format(iteration_count))
    print("Final value = {: 3.6f}".format(x))
    print()

# %%
# Побудова графіка функції
y = np.arange(-5,7,0.01)
plt.figure(figsize=(12,10))
plt.grid(color='gray', linestyle='-', linewidth=1)
plt.plot(y, f(y))

# Методи простої ітерації для трьох точок
simple_iteration(6, 'r', 0.01)
simple_iteration(0, 'b', -0.01)
simple_iteration(-4, 'g', 0.01)
# Out:
# Start point is 6
# From  6.000000 to  5.570000   f(x)= 43.00000000
# From  5.570000 to  5.342809   f(x)= 22.71909300
# From  5.342809 to  5.203493   f(x)= 13.93163886
# From  5.203493 to  5.111875   f(x)= 9.16172355
# From  5.111875 to  5.049160   f(x)= 6.27159000
# From  5.049160 to  5.005128   f(x)= 4.40316936
# From  5.005128 to  4.973689   f(x)= 3.14386924
# From  4.973689 to  4.950980   f(x)= 2.27089313
# From  4.950980 to  4.934443   f(x)= 1.65376093
# From  4.934443 to  4.922329   f(x)= 1.21138706
# From  4.922329 to  4.913418   f(x)= 0.89109744
# From  4.913418 to  4.906843   f(x)= 0.65750992
# From  4.906843 to  4.901980   f(x)= 0.48624762
# From  4.901980 to  4.898378   f(x)= 0.36019050
# From  4.898378 to  4.895707   f(x)= 0.26713947
# From  4.895707 to  4.893724   f(x)= 0.19830634
# From  4.893724 to  4.892251   f(x)= 0.14730791
# From  4.892251 to  4.891156   f(x)= 0.10947913
# From  4.891156 to  4.890342   f(x)= 0.08139482
# From  4.890342 to  4.889737   f(x)= 0.06053147
# From  4.889737 to  4.889286   f(x)= 0.04502504
# From  4.889286 to  4.888951   f(x)= 0.03349598
# From  4.888951 to  4.888702   f(x)= 0.02492185
# From  4.888702 to  4.888517   f(x)= 0.01854403
# From  4.888517 to  4.888379   f(x)= 0.01379924
# From  4.888379 to  4.888276   f(x)= 0.01026895
# From  4.888276 to  4.888200   f(x)= 0.00764209
# Ended with 27 iterations
# Final value =  4.888276
#
# Start point is 0
# From  0.000000 to  0.130000   f(x)= 13.00000000
# From  0.130000 to  0.250246   f(x)= 12.02459700
# From  0.250246 to  0.360381   f(x)= 11.01345719
# From  0.360381 to  0.460427   f(x)= 10.00464378
# From  0.460427 to  0.550693   f(x)= 9.02664643
# From  0.550693 to  0.631684   f(x)= 8.09909791
# From  0.631684 to  0.704026   f(x)= 7.23416621
# From  0.704026 to  0.768408   f(x)= 6.43815894
# From  0.768408 to  0.825538   f(x)= 5.71305144
# From  0.825538 to  0.876116   f(x)= 5.05779473
# From  0.876116 to  0.920810   f(x)= 4.46935788
# From  0.920810 to  0.960245   f(x)= 3.94351571
# From  0.960245 to  0.994999   f(x)= 3.47541823
# From  0.994999 to  1.025599   f(x)= 3.05998621
# From  1.025599 to  1.052521   f(x)= 2.69217447
# From  1.052521 to  1.076192   f(x)= 2.36713852
# From  1.076192 to  1.096995   f(x)= 2.08033253
# From  1.096995 to  1.115271   f(x)= 1.82755998
# From  1.115271 to  1.131321   f(x)= 1.60499260
# From  1.131321 to  1.145413   f(x)= 1.40916870
# From  1.145413 to  1.157782   f(x)= 1.23697889
# From  1.157782 to  1.168639   f(x)= 1.08564428
# From  1.168639 to  1.178166   f(x)= 0.95269108
# From  1.178166 to  1.186525   f(x)= 0.83592377
# From  1.186525 to  1.193859   f(x)= 0.73339836
# From  1.193859 to  1.200293   f(x)= 0.64339680
# From  1.200293 to  1.205937   f(x)= 0.56440295
# From  1.205937 to  1.210888   f(x)= 0.49508042
# From  1.210888 to  1.215230   f(x)= 0.43425230
# From  1.215230 to  1.219039   f(x)= 0.38088300
# From  1.219039 to  1.222380   f(x)= 0.33406172
# From  1.222380 to  1.225310   f(x)= 0.29298790
# From  1.225310 to  1.227879   f(x)= 0.25695810
# From  1.227879 to  1.230133   f(x)= 0.22535444
# From  1.230133 to  1.232109   f(x)= 0.19763431
# From  1.232109 to  1.233842   f(x)= 0.17332136
# From  1.233842 to  1.235362   f(x)= 0.15199743
# From  1.235362 to  1.236695   f(x)= 0.13329553
# From  1.236695 to  1.237864   f(x)= 0.11689361
# From  1.237864 to  1.238889   f(x)= 0.10250908
# From  1.238889 to  1.239788   f(x)= 0.08989403
# From  1.239788 to  1.240576   f(x)= 0.07883092
# From  1.240576 to  1.241268   f(x)= 0.06912896
# From  1.241268 to  1.241874   f(x)= 0.06062077
# From  1.241874 to  1.242406   f(x)= 0.05315952
# From  1.242406 to  1.242872   f(x)= 0.04661644
# From  1.242872 to  1.243281   f(x)= 0.04087858
# From  1.243281 to  1.243639   f(x)= 0.03584688
# From  1.243639 to  1.243953   f(x)= 0.03143445
# From  1.243953 to  1.244229   f(x)= 0.02756510
# From  1.244229 to  1.244471   f(x)= 0.02417199
# From  1.244471 to  1.244683   f(x)= 0.02119652
# From  1.244683 to  1.244869   f(x)= 0.01858729
# From  1.244869 to  1.245032   f(x)= 0.01629923
# From  1.245032 to  1.245174   f(x)= 0.01429281
# From  1.245174 to  1.245300   f(x)= 0.01253337
# From  1.245300 to  1.245410   f(x)= 0.01099051
# From  1.245410 to  1.245506   f(x)= 0.00963756
# Ended with 58 iterations
# Final value =  1.245410
#
# Start point is -4
# From -4.000000 to -3.130000   f(x)=-87.00000000
# From -3.130000 to -2.780581   f(x)=-34.94189700
# From -2.780581 to -2.580972   f(x)=-19.96088236
# From -2.580972 to -2.453254   f(x)=-12.77179818
# From -2.453254 to -2.366596   f(x)=-8.66584891
# From -2.366596 to -2.305679   f(x)=-6.09170247
# From -2.305679 to -2.261857   f(x)=-4.38221013
# From -2.261857 to -2.229830   f(x)=-3.20263286
# From -2.229830 to -2.206162   f(x)=-2.36679557
# From -2.206162 to -2.188530   f(x)=-1.76320037
# From -2.188530 to -2.175318   f(x)=-1.32127464
# From -2.175318 to -2.165373   f(x)=-0.99442021
# From -2.165373 to -2.157865   f(x)=-0.75084705
# From -2.157865 to -2.152182   f(x)=-0.56831043
# From -2.152182 to -2.147872   f(x)=-0.43093519
# From -2.147872 to -2.144600   f(x)=-0.32721740
# From -2.144600 to -2.142113   f(x)=-0.24872159
# From -2.142113 to -2.140221   f(x)=-0.18920553
# From -2.140221 to -2.138781   f(x)=-0.14401733
# From -2.138781 to -2.137684   f(x)=-0.10967150
# From -2.137684 to -2.136849   f(x)=-0.08354559
# From -2.136849 to -2.136212   f(x)=-0.06366019
# From -2.136212 to -2.135727   f(x)=-0.04851764
# From -2.135727 to -2.135357   f(x)=-0.03698264
# From -2.135357 to -2.135075   f(x)=-0.02819336
# From -2.135075 to -2.134860   f(x)=-0.02149485
# From -2.134860 to -2.134696   f(x)=-0.01638897
# From -2.134696 to -2.134571   f(x)=-0.01249658
# From -2.134571 to -2.134476   f(x)=-0.00952901
# Ended with 29 iterations
# Final value = -2.134571

# %% [markdown]
# ## Метод релаксації

# %%
# Побудуємо графік функції
y = np.arange(-5,7,0.01)
plt.figure(figsize=(12,10))
plt.grid(color='gray', linestyle='-', linewidth=1)
plt.plot(y, f(y))

#
def get_best_lambda_for_range(rstart, rend):
    return 2/( max(abs(df(np.arange(-4,-2,0.01)))) + min(abs(df(np.arange(-4,-2,0.01)))))

simple_iteration(6,  'r',  get_best_lambda_for_range(-4, -1))
simple_iteration(0,  'b', -get_best_lambda_for_range(0, 2))
simple_iteration(-4, 'g',  get_best_lambda_for_range(4, 6))
# Out:
# Start point is 6
# From  6.000000 to  5.087052   f(x)= 43.00000000
# From  5.087052 to  4.969824   f(x)= 5.52146645
# From  4.969824 to  4.923857   f(x)= 2.16504806
# From  4.923857 to  4.904083   f(x)= 0.93131991
# From  4.904083 to  4.895280   f(x)= 0.41465371
# From  4.895280 to  4.891303   f(x)= 0.18731498
# From  4.891303 to  4.889495   f(x)= 0.08516074
# From  4.889495 to  4.888670   f(x)= 0.03882909
# From  4.888670 to  4.888294   f(x)= 0.01772730
# From  4.888294 to  4.888122   f(x)= 0.00809816
# From  4.888122 to  4.888043   f(x)= 0.00370040
# Ended with 11 iterations
# Final value =  4.888122
#
# Start point is 0
# From  0.000000 to -0.276008   f(x)= 13.00000000
# From -0.276008 to -0.586119   f(x)= 14.60630617
# From -0.586119 to -0.915786   f(x)= 15.52733876
# From -0.915786 to -1.240367   f(x)= 15.28781005
# From -1.240367 to -1.529542   f(x)= 13.62021311
# From -1.529542 to -1.758213   f(x)= 10.77043479
# From -1.758213 to -1.917598   f(x)= 7.50705019
# From -1.917598 to -2.016602   f(x)= 4.66310077
# From -2.016602 to -2.072835   f(x)= 2.64859845
# From -2.072835 to -2.102921   f(x)= 1.41702310
# From -2.102921 to -2.118455   f(x)= 0.73165085
# From -2.118455 to -2.126320   f(x)= 0.37047797
# From -2.126320 to -2.130263   f(x)= 0.18569028
# From -2.130263 to -2.132229   f(x)= 0.09258835
# From -2.132229 to -2.133206   f(x)= 0.04604547
# From -2.133206 to -2.133692   f(x)= 0.02286914
# From -2.133692 to -2.133933   f(x)= 0.01135090
# From -2.133933 to -2.134052   f(x)= 0.00563210
# From -2.134052 to -2.134112   f(x)= 0.00279409
# Ended with 19 iterations
# Final value = -2.134052
#
# Start point is -4
# From -4.000000 to -2.152872   f(x)=-87.00000000
# From -2.152872 to -2.143369   f(x)=-0.44758609
# From -2.143369 to -2.138714   f(x)=-0.21924896
# From -2.138714 to -2.136419   f(x)=-0.10808628
# From -2.136419 to -2.135285   f(x)=-0.05345099
# From -2.135285 to -2.134723   f(x)=-0.02647318
# From -2.134723 to -2.134444   f(x)=-0.01312155
# From -2.134444 to -2.134306   f(x)=-0.00650619
# From -2.134306 to -2.134237   f(x)=-0.00322663
# Ended with  9 iterations
# Final value = -2.134306
